# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Convolution2D
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.layers import Flatten

# %%
train_datagen = ImageDataGenerator(rescale = 1./255,shear_range = 0.2,zoom_range = 0.2,horizontal_flip = True)
test_datagen =ImageDataGenerator(rescale = 1)

# %%
x_train = train_datagen.flow_from_directory('/content/drive/MyDrive/DATASET/Train',target_size = (64,64),batch_size = 10, class_mode = 'binary')
x_test =  test_datagen.flow_from_directory('/content/drive/MyDrive/DATASET/Test',target_size = (64,64),batch_size = 10, class_mode = 'binary')
# Out:
# Found 131 images belonging to 2 classes.
# Found 141 images belonging to 2 classes.

# %%
print(x_train.class_indices)
# Out:
# {'Benign': 0, 'Malignant': 1}

# %%
model = Sequential()

# %%
model.add(Convolution2D(32,(3,3),input_shape=(64,64,3),activation='relu'))
model.add(MaxPooling2D(2,2))
model.add(Flatten()) 
model.add(Dense(kernel_initializer='uniform',activation='relu',units=150))
model.add(Dense(kernel_initializer='uniform',activation='sigmoid',units=1))
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['acc'])

# %%
model.fit(x_train,steps_per_epoch = len(x_train)//10,epochs=20, validation_data=x_test,validation_steps = len(x_test)//10)
# Out:
# Epoch 1/20
# 1/1 [==============================] - 9s 9s/step - loss: 0.6977 - acc: 0.4000 - val_loss: 219.0218 - val_acc: 0.8000
# Epoch 2/20
# 1/1 [==============================] - 6s 6s/step - loss: 1.8990 - acc: 0.5000 - val_loss: 50.8694 - val_acc: 0.8000
# Epoch 3/20
# 1/1 [==============================] - 5s 5s/step - loss: 0.8932 - acc: 0.4000 - val_loss: 165.4934 - val_acc: 0.6000
# Epoch 4/20
# 1/1 [==============================] - 3s 3s/step - loss: 0.8887 - acc: 0.5000 - val_loss: 339.5682 - val_acc: 0.3000
# Epoch 5/20
# 1/1 [==============================] - 3s 3s/step - loss: 1.3285 - acc: 0.3000 - val_loss: 334.1486 - val_acc: 0.3000
# Epoch 6/20
# 1/1 [==============================] - 3s 3s/step - loss: 0.8140 - acc: 0.6000 - val_loss: 341.7343 - val_acc: 0.1000
# Epoch 7/20
# 1/1 [==============================] - 3s 3s/step - loss: 1.4207 - acc: 0.2000 - val_loss: 255.2480 - val_acc: 0.2000
# Epoch 8/20
# ...

# %%
model.save("breastcancer.h5")

# %%
from keras.models  import load_model
from tensorflow.keras.preprocessing import image
import numpy as np

# %%
model = load_model("breastcancer.h5")

# %%
img = image.load_img(r"/content/drive/MyDrive/DATASET/Test/Malignant/8863_idx5_x1801_y1301_class1.png",target_size = (64,64))

# %%
x  = image.img_to_array(img)
x = np.expand_dims(x,axis = 0)

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d (Conv2D)             (None, 62, 62, 32)        896
#
#  max_pooling2d (MaxPooling2D  (None, 31, 31, 32)       0
#  )
#
#  flatten (Flatten)           (None, 30752)             0
#
#  dense (Dense)               (None, 150)               4612950
#
#  dense_1 (Dense)             (None, 1)                 151
#
# ...
# Total params: 4,613,997
# Trainable params: 4,613,997
# Non-trainable params: 0
# _________________________________________________________________

# %%
pred = model.predict(x)
# Out:
# 1/1 [==============================] - 0s 111ms/step

# %%
pred
# Out:
# array([[1.]], dtype=float32)

# %%
model.save('breastcancer.h5')
